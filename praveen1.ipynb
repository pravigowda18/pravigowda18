# %%
print("hello world");
# Out:
# hello world

# %%
5+4
# Out:
# 9

# %%
10-5
# Out:
# 5

# %%
15*2
# Out:
# 30

# %%
18/2
# Out:
# 9.0

# %%
19/2
# Out:
# 9.5

# %%
19%2
# Out:
# 1

# %%
print("Enter a number")
# Out:
# Enter a number

# %%
int a,b,c,d;
a=10;
b=12;
c=a+b;
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_2928/1606776951.py", line 1
#     int a,b,c,d;
#         ^
# SyntaxError: invalid syntax
